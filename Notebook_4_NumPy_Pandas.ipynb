# %% [markdown]
# # Notebook 4: NumPy & Pandas

# %%
# NumPy basics
import numpy as np
arr = np.array([1,2,3])
print(arr, arr.mean(), arr.reshape(3,1))

# %%
# Pandas basics
import pandas as pd
df = pd.DataFrame({'name':['A','B'], 'score':[80,90]})
print(df)
print(df.describe())
